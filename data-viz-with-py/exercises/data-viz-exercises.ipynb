# %% [markdown]
# ## Exercises: Data Visualizations in Python
#
# We will be using [this dataset](https://www.kaggle.com/datasets/arnavvvvv/spotify-music/data) from Kaggle on Top Spotify Songs. No need to dowload it, it is already in the `exercises` directory.

# %% [markdown]
# ### Setting Up Your Data
#
# Before you dive into data visualizations, you need to set up your dataframe and make sure that it is cleaned and ready to go.

# %%
# import all librarys and modules needed
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib import style

df = pd.read_csv("./Popular_Spotify_Songs.csv", encoding='latin-1')

df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                147  141381703                  43  ...  125   B  Major
# 1                 48  133716286                  48  ...   92  C#  Major
# 2                113  140003974                  94  ...  138   F  Major
# 3                100  800840817                 116  ...  170   A  Major
# 4                 50  303236322                  84  ...  144   A  Minor
#
#   danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0             80         89       83             31                   0
# 1             71         61       74              7                   0
# 2             51         32       53             17                   0
# 3             55         58       72             11                   0
# 4             65         23       80             14                  63
#
#    liveness_%  speechiness_%
# 0           8              4
# 1          10              4
# 2          31              6
# 3          11             15
# 4          11              6
#
# [5 rows x 24 columns]

# %%
# import and clean data
# display(df.isnull().count())
display(df.duplicated().count)
# Out:
# <bound method Series.count of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 948    False
# 949    False
# 950    False
# 951    False
# 952    False
# Length: 953, dtype: bool>

# %% [markdown]
# ### Creating Visualizations
#
# Now that the data is ready, you can use the dataset to create a number of different visualizations. You do not need to make the visualizations perfect; this is just for practice.
#
# #### Line Chart

# %%
# Single line chart
# plt.plot(df['released_year'],df['released_month'])

plt.plot(df['released_year'])
plt.show()

# %%
# Multiple Line chart 
plt.plot(df['released_year'],df['released_month'])

plt.show()

# %% [markdown]
# #### Bar Chart

# %%
# Vertical bar chart
plt.bar(df['released_year'],df['released_month'])
# Out:
# <BarContainer object of 953 artists>

# %%
# Horizontal bar chart
sb.barplot( y=df['released_month'],x=df['released_year'],orient="y")
# Out:
# <Axes: xlabel='released_year', ylabel='released_month'>

# %%
# Grouped bar chart
# sb.barplot( y=df['released_month'],x=df['released_year'],orient="y")

sb.barplot(y="released_day",x="released_month",hue="released_year",data=df)
# sns.barplot(x='Day', y='Customers', hue='Time', data=df)
# Out:
# <Axes: xlabel='released_month', ylabel='released_day'>

# %% [markdown]
# #### Scatter Plot

# %%
# scatter plot
plt.scatter(data=df,y="released_day",x="released_month")

# %% [markdown]
# #### Histogram

# %%
# histogram
plt.hist(data=df,x="released_month")
# Out:
# (array([195.,  86.,  66., 128.,  86.,  62.,  46.,  56.,  73., 155.]),
#  array([ 1. ,  2.1,  3.2,  4.3,  5.4,  6.5,  7.6,  8.7,  9.8, 10.9, 12. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Pie Chart

# %%
# pie chart
# plt.pie(data=df,x="released_month",labels="released_day")
plt.pie(df['artist_count'],labels=df["released_year"])
# Out:
# ([<matplotlib.patches.Wedge at 0x195bfccf4d0>,
#   <matplotlib.patches.Wedge at 0x195bfc95730>,
#   <matplotlib.patches.Wedge at 0x195bfd18620>,
#   <matplotlib.patches.Wedge at 0x195bfccefc0>,
#   <matplotlib.patches.Wedge at 0x195bfd18ce0>,
#   <matplotlib.patches.Wedge at 0x195bfd19100>,
#   <matplotlib.patches.Wedge at 0x195bfd19730>,
#   <matplotlib.patches.Wedge at 0x195bfd19dc0>,
#   <matplotlib.patches.Wedge at 0x195bfd1a450>,
#   <matplotlib.patches.Wedge at 0x195bfd1a9f0>,
#   <matplotlib.patches.Wedge at 0x195bfd1b050>,
#   <matplotlib.patches.Wedge at 0x195bfd1b6b0>,
#   <matplotlib.patches.Wedge at 0x195bfd1bb30>,
#   <matplotlib.patches.Wedge at 0x195bfd1be30>,
#   <matplotlib.patches.Wedge at 0x195bfb91b80>,
#   <matplotlib.patches.Wedge at 0x195bfd50080>,
#   <matplotlib.patches.Wedge at 0x195bfd504a0>,
#   <matplotlib.patches.Wedge at 0x195bfd509b0>,
#   <matplotlib.patches.Wedge at 0x195bfd50e30>,
#   <matplotlib.patches.Wedge at 0x195bfd512b0>,
#   <matplotlib.patches.Wedge at 0x195bfd51700>,
#   <matplotlib.patches.Wedge at 0x195bfd51b20>,
#   <matplotlib.patches.Wedge at 0x195bfd51fa0>,
#   <matplotlib.patches.Wedge at 0x195bfd52480>,
#   <matplotlib.patches.Wedge at 0x195bfd52930>,
#   <matplotlib.patches.Wedge at 0x195bfd52c60>,
#   <matplotlib.patches.Wedge at 0x195bfd53230>,
#   <matplotlib.patches.Wedge at 0x195bfd53680>,
#   <matplotlib.patches.Wedge at 0x195bfd539b0>,
#   <matplotlib.patches.Wedge at 0x195bfd53ef0>,
#   <matplotlib.patches.Wedge at 0x195bfd80260>,
#   <matplotlib.patches.Wedge at 0x195bfd80830>,
#   <matplotlib.patches.Wedge at 0x195bfd80cb0>,
#   <matplotlib.patches.Wedge at 0x195bfd81130>,
#   <matplotlib.patches.Wedge at 0x195bfd815e0>,
#   <matplotlib.patches.Wedge at 0x195bfd81a90>,
#   <matplotlib.patches.Wedge at 0x195bfd81f10>,
#   <matplotlib.patches.Wedge at 0x195bfd823c0>,
#   <matplotlib.patches.Wedge at 0x195bfd827e0>,
#   <matplotlib.patches.Wedge at 0x195bfd82c00>,
#   <matplotlib.patches.Wedge at 0x195bfd83080>,
#   <matplotlib.patches.Wedge at 0x195bfd834a0>,
#   <matplotlib.patches.Wedge at 0x195bfd838c0>,
#   <matplotlib.patches.Wedge at 0x195bfd83ce0>,
#   <matplotlib.patches.Wedge at 0x195bfdac1a0>,
#   <matplotlib.patches.Wedge at 0x195bfdac5c0>,
#   <matplotlib.patches.Wedge at 0x195bfdaca70>,
#   <matplotlib.patches.Wedge at 0x195bfdacf20>,
#   <matplotlib.patches.Wedge at 0x195bfdad3d0>,
#   <matplotlib.patches.Wedge at 0x195bfdad7f0>,
#   <matplotlib.patches.Wedge at 0x195bfdadc70>,
#   <matplotlib.patches.Wedge at 0x195bfdae0c0>,
#   <matplotlib.patches.Wedge at 0x195bfdae540>,
#   <matplotlib.patches.Wedge at 0x195bfdae990>,
#   <matplotlib.patches.Wedge at 0x195bfdaec60>,
#   <matplotlib.patches.Wedge at 0x195bfdaf230>,
#   <matplotlib.patches.Wedge at 0x195bfdaf650>,
#   <matplotlib.patches.Wedge at 0x195bfdafaa0>,
#   <matplotlib.patches.Wedge at 0x195bfdaff80>,
#   <matplotlib.patches.Wedge at 0x195bfdf4440>,
#   <matplotlib.patches.Wedge at 0x195bfdf48f0>,
#   <matplotlib.patches.Wedge at 0x195bfdf4dd0>,
#   <matplotlib.patches.Wedge at 0x195bfdf5250>,
#   <matplotlib.patches.Wedge at 0x195bfdf56d0>,
#   <matplotlib.patches.Wedge at 0x195bfdf5b80>,
#   <matplotlib.patches.Wedge at 0x195bfdf6000>,
#   <matplotlib.patches.Wedge at 0x195bfdf6480>,
#   <matplotlib.patches.Wedge at 0x195bfdf6960>,
#   <matplotlib.patches.Wedge at 0x195bfdf6de0>,
#   <matplotlib.patches.Wedge at 0x195bfdf7290>,
#   <matplotlib.patches.Wedge at 0x195bfdf7710>,
#   <matplotlib.patches.Wedge at 0x195bfdf7b90>,
#   <matplotlib.patches.Wedge at 0x195bfe24050>,
#   <matplotlib.patches.Wedge at 0x195bfe244d0>,
#   <matplotlib.patches.Wedge at 0x195bfe24920>,
#   <matplotlib.patches.Wedge at 0x195bfe24da0>,
#   <matplotlib.patches.Wedge at 0x195bfe25250>,
#   <matplotlib.patches.Wedge at 0x195bfe256a0>,
#   <matplotlib.patches.Wedge at 0x195bfe25b50>,
#   <matplotlib.patches.Wedge at 0x195bfe25fd0>,
#   <matplotlib.patches.Wedge at 0x195bfe26450>,
#   <matplotlib.patches.Wedge at 0x195bfe26780>,
#   <matplotlib.patches.Wedge at 0x195bfe26d20>,
#   <matplotlib.patches.Wedge at 0x195bfe271a0>,
#   <matplotlib.patches.Wedge at 0x195bfe27620>,
#   <matplotlib.patches.Wedge at 0x195bfe27aa0>,
#   <matplotlib.patches.Wedge at 0x195bfe27f50>,
#   <matplotlib.patches.Wedge at 0x195bfe543e0>,
#   <matplotlib.patches.Wedge at 0x195bfe548c0>,
#   <matplotlib.patches.Wedge at 0x195bfe54d10>,
#   <matplotlib.patches.Wedge at 0x195bfe551c0>,
#   <matplotlib.patches.Wedge at 0x195bfe55610>,
#   <matplotlib.patches.Wedge at 0x195bfe55a30>,
#   <matplotlib.patches.Wedge at 0x195bfe55ee0>,
#   <matplotlib.patches.Wedge at 0x195bfe563c0>,
#   <matplotlib.patches.Wedge at 0x195bfe56840>,
#   <matplotlib.patches.Wedge at 0x195bfe56cc0>,
#   <matplotlib.patches.Wedge at 0x195bfe56ff0>,
#   <matplotlib.patches.Wedge at 0x195bfe57590>,
#   <matplotlib.patches.Wedge at 0x195bfe57a10>,
#   <matplotlib.patches.Wedge at 0x195bfe57ec0>,
#   <matplotlib.patches.Wedge at 0x195bfe843b0>,
#   <matplotlib.patches.Wedge at 0x195bfe84890>,
#   <matplotlib.patches.Wedge at 0x195bfe84d40>,
#   <matplotlib.patches.Wedge at 0x195bfe84710>,
#   <matplotlib.patches.Wedge at 0x195bfe855e0>,
#   <matplotlib.patches.Wedge at 0x195bfe85a60>,
#   <matplotlib.patches.Wedge at 0x195bfe85f10>,
#   <matplotlib.patches.Wedge at 0x195bfe86390>,
#   <matplotlib.patches.Wedge at 0x195bfe867e0>,
#   <matplotlib.patches.Wedge at 0x195bfe86c30>,
#   <matplotlib.patches.Wedge at 0x195bfe86f60>,
#   <matplotlib.patches.Wedge at 0x195bfe87530>,
#   <matplotlib.patches.Wedge at 0x195bfe879b0>,
#   <matplotlib.patches.Wedge at 0x195bfe87e30>,
#   <matplotlib.patches.Wedge at 0x195bfeb42c0>,
#   <matplotlib.patches.Wedge at 0x195bfeb4740>,
#   <matplotlib.patches.Wedge at 0x195bfeb4c20>,
#   <matplotlib.patches.Wedge at 0x195bfeb5070>,
#   <matplotlib.patches.Wedge at 0x195bfeb5520>,
#   <matplotlib.patches.Wedge at 0x195bfeb59d0>,
#   <matplotlib.patches.Wedge at 0x195bfeb5e80>,
#   <matplotlib.patches.Wedge at 0x195bfeb6330>,
#   <matplotlib.patches.Wedge at 0x195bfeb67e0>,
#   <matplotlib.patches.Wedge at 0x195bfeb6c60>,
#   <matplotlib.patches.Wedge at 0x195bfeb70e0>,
#   <matplotlib.patches.Wedge at 0x195bfeb7590>,
#   <matplotlib.patches.Wedge at 0x195bfeb7a10>,
#   <matplotlib.patches.Wedge at 0x195bfeb7ec0>,
#   <matplotlib.patches.Wedge at 0x195bfee8320>,
#   <matplotlib.patches.Wedge at 0x195bfee8620>,
#   <matplotlib.patches.Wedge at 0x195bfee8b90>,
#   <matplotlib.patches.Wedge at 0x195bfee8fe0>,
#   <matplotlib.patches.Wedge at 0x195bfee9430>,
#   <matplotlib.patches.Wedge at 0x195bfee98b0>,
#   <matplotlib.patches.Wedge at 0x195bfee9d30>,
#   <matplotlib.patches.Wedge at 0x195bfeea1e0>,
#   <matplotlib.patches.Wedge at 0x195bfeea690>,
#   <matplotlib.patches.Wedge at 0x195bfeeaae0>,
#   <matplotlib.patches.Wedge at 0x195bfeeaf30>,
#   <matplotlib.patches.Wedge at 0x195bfeeb3b0>,
#   <matplotlib.patches.Wedge at 0x195bfeeb830>,
#   <matplotlib.patches.Wedge at 0x195bfeebd10>,
#   <matplotlib.patches.Wedge at 0x195bff201a0>,
#   <matplotlib.patches.Wedge at 0x195bff20650>,
#   <matplotlib.patches.Wedge at 0x195bff20ad0>,
#   <matplotlib.patches.Wedge at 0x195bff20f50>,
#   <matplotlib.patches.Wedge at 0x195bff21370>,
#   <matplotlib.patches.Wedge at 0x195bff218b0>,
#   <matplotlib.patches.Wedge at 0x195bff21d00>,
#   <matplotlib.patches.Wedge at 0x195bff221b0>,
#   <matplotlib.patches.Wedge at 0x195bff22660>,
#   <matplotlib.patches.Wedge at 0x195bff22b10>,
#   <matplotlib.patches.Wedge at 0x195bff22ff0>,
#   <matplotlib.patches.Wedge at 0x195bff23410>,
#   <matplotlib.patches.Wedge at 0x195bff238c0>,
#   <matplotlib.patches.Wedge at 0x195bff23da0>,
#   <matplotlib.patches.Wedge at 0x195bff50260>,
#   <matplotlib.patches.Wedge at 0x195bff506e0>,
#   <matplotlib.patches.Wedge at 0x195bff50b90>,
#   <matplotlib.patches.Wedge at 0x195bff51010>,
#   <matplotlib.patches.Wedge at 0x195bff51490>,
#   <matplotlib.patches.Wedge at 0x195bff51940>,
#   <matplotlib.patches.Wedge at 0x195bff51df0>,
#   <matplotlib.patches.Wedge at 0x195bff522a0>,
#   <matplotlib.patches.Wedge at 0x195bff52720>,
#   <matplotlib.patches.Wedge at 0x195bff52bd0>,
#   <matplotlib.patches.Wedge at 0x195bff53020>,
#   <matplotlib.patches.Wedge at 0x195bff53470>,
#   <matplotlib.patches.Wedge at 0x195bff53920>,
#   <matplotlib.patches.Wedge at 0x195bff53dd0>,
#   <matplotlib.patches.Wedge at 0x195bff84200>,
#   <matplotlib.patches.Wedge at 0x195bff846e0>,
#   <matplotlib.patches.Wedge at 0x195bff84b60>,
#   <matplotlib.patches.Wedge at 0x195bff85010>,
#   <matplotlib.patches.Wedge at 0x195bff85460>,
#   <matplotlib.patches.Wedge at 0x195bff858e0>,
#   <matplotlib.patches.Wedge at 0x195bff85d90>,
#   <matplotlib.patches.Wedge at 0x195bff861e0>,
#   <matplotlib.patches.Wedge at 0x195bff86630>,
#   <matplotlib.patches.Wedge at 0x195bff86ae0>,
#   <matplotlib.patches.Wedge at 0x195bff86f90>,
#   <matplotlib.patches.Wedge at 0x195bff873b0>,
#   <matplotlib.patches.Wedge at 0x195bff87860>,
#   <matplotlib.patches.Wedge at 0x195bff87ce0>,
#   <matplotlib.patches.Wedge at 0x195bffb8170>,
#   <matplotlib.patches.Wedge at 0x195bffb85c0>,
#   <matplotlib.patches.Wedge at 0x195bffb8a10>,
#   <matplotlib.patches.Wedge at 0x195bffb8ec0>,
#   <matplotlib.patches.Wedge at 0x195bffb92e0>,
#   <matplotlib.patches.Wedge at 0x195bffb9760>,
#   <matplotlib.patches.Wedge at 0x195bffb9c10>,
#   <matplotlib.patches.Wedge at 0x195bffba0c0>,
#   <matplotlib.patches.Wedge at 0x195bffba540>,
#   <matplotlib.patches.Wedge at 0x195bffba9f0>,
#   <matplotlib.patches.Wedge at 0x195bffbae70>,
#   <matplotlib.patches.Wedge at 0x195bffbb2f0>,
#   <matplotlib.patches.Wedge at 0x195bffbb770>,
#   <matplotlib.patches.Wedge at 0x195bffbbbf0>,
#   <matplotlib.patches.Wedge at 0x195bffec110>,
#   <matplotlib.patches.Wedge at 0x195bffec590>,
#   <matplotlib.patches.Wedge at 0x195bffeca10>,
#   <matplotlib.patches.Wedge at 0x195bffecef0>,
#   <matplotlib.patches.Wedge at 0x195bffed3d0>,
#   <matplotlib.patches.Wedge at 0x195bffed850>,
#   <matplotlib.patches.Wedge at 0x195bffedd30>,
#   <matplotlib.patches.Wedge at 0x195bffee210>,
#   <matplotlib.patches.Wedge at 0x195bffee690>,
#   <matplotlib.patches.Wedge at 0x195bffeeb10>,
#   <matplotlib.patches.Wedge at 0x195bffeefc0>,
#   <matplotlib.patches.Wedge at 0x195bffef440>,
#   <matplotlib.patches.Wedge at 0x195bffef8c0>,
#   <matplotlib.patches.Wedge at 0x195bffefd70>,
#   <matplotlib.patches.Wedge at 0x195c1028260>,
#   <matplotlib.patches.Wedge at 0x195c10286e0>,
#   <matplotlib.patches.Wedge at 0x195c1028b90>,
#   <matplotlib.patches.Wedge at 0x195c1029010>,
#   <matplotlib.patches.Wedge at 0x195c1029430>,
#   <matplotlib.patches.Wedge at 0x195c10298e0>,
#   <matplotlib.patches.Wedge at 0x195c1029dc0>,
#   <matplotlib.patches.Wedge at 0x195c102a210>,
#   <matplotlib.patches.Wedge at 0x195c102a6c0>,
#   <matplotlib.patches.Wedge at 0x195c102ab70>,
#   <matplotlib.patches.Wedge at 0x195c102b020>,
#   <matplotlib.patches.Wedge at 0x195c102b500>,
#   <matplotlib.patches.Wedge at 0x195c102b950>,
#   <matplotlib.patches.Wedge at 0x195c102bda0>,
#   <matplotlib.patches.Wedge at 0x195c1058260>,
#   <matplotlib.patches.Wedge at 0x195c1058710>,
#   <matplotlib.patches.Wedge at 0x195c1058b90>,
#   <matplotlib.patches.Wedge at 0x195c1059040>,
#   <matplotlib.patches.Wedge at 0x195c1059490>,
#   <matplotlib.patches.Wedge at 0x195c1059910>,
#   <matplotlib.patches.Wedge at 0x195c1059d60>,
#   <matplotlib.patches.Wedge at 0x195c105a210>,
#   <matplotlib.patches.Wedge at 0x195c105a690>,
#   <matplotlib.patches.Wedge at 0x195c105ab10>,
#   <matplotlib.patches.Wedge at 0x195c10584d0>,
#   <matplotlib.patches.Wedge at 0x195c105b410>,
#   <matplotlib.patches.Wedge at 0x195c105b890>,
#   <matplotlib.patches.Wedge at 0x195c105bd10>,
#   <matplotlib.patches.Wedge at 0x195c108c1a0>,
#   <matplotlib.patches.Wedge at 0x195c108c650>,
#   <matplotlib.patches.Wedge at 0x195c108cad0>,
#   <matplotlib.patches.Wedge at 0x195c108cf80>,
#   <matplotlib.patches.Wedge at 0x195c108d430>,
#   <matplotlib.patches.Wedge at 0x195c108d8b0>,
#   <matplotlib.patches.Wedge at 0x195c108dd90>,
#   <matplotlib.patches.Wedge at 0x195c108e210>,
#   <matplotlib.patches.Wedge at 0x195c108e690>,
#   <matplotlib.patches.Wedge at 0x195c108eb40>,
#   <matplotlib.patches.Wedge at 0x195c108ef90>,
#   <matplotlib.patches.Wedge at 0x195c108f410>,
#   <matplotlib.patches.Wedge at 0x195c108f890>,
#   <matplotlib.patches.Wedge at 0x195c108fd10>,
#   <matplotlib.patches.Wedge at 0x195c10c01d0>,
#   <matplotlib.patches.Wedge at 0x195c10c0620>,
#   <matplotlib.patches.Wedge at 0x195c10c0a70>,
#   <matplotlib.patches.Wedge at 0x195c10c0e90>,
#   <matplotlib.patches.Wedge at 0x195c10c1310>,
#   <matplotlib.patches.Wedge at 0x195c10c1790>,
#   <matplotlib.patches.Wedge at 0x195c10c1c10>,
#   <matplotlib.patches.Wedge at 0x195c10c2090>,
#   <matplotlib.patches.Wedge at 0x195c10c2510>,
#   <matplotlib.patches.Wedge at 0x195c10c29c0>,
#   <matplotlib.patches.Wedge at 0x195c10c2ea0>,
#   <matplotlib.patches.Wedge at 0x195c10c3350>,
#   <matplotlib.patches.Wedge at 0x195c10c3770>,
#   <matplotlib.patches.Wedge at 0x195c10c3bf0>,
#   <matplotlib.patches.Wedge at 0x195c10f40b0>,
#   <matplotlib.patches.Wedge at 0x195c10f4560>,
#   <matplotlib.patches.Wedge at 0x195c10f4a10>,
#   <matplotlib.patches.Wedge at 0x195c10f4e90>,
#   <matplotlib.patches.Wedge at 0x195c10f5310>,
#   <matplotlib.patches.Wedge at 0x195c10f5790>,
#   <matplotlib.patches.Wedge at 0x195c10f5c10>,
#   <matplotlib.patches.Wedge at 0x195c10f6090>,
#   <matplotlib.patches.Wedge at 0x195c10f64b0>,
#   <matplotlib.patches.Wedge at 0x195c10f6990>,
#   <matplotlib.patches.Wedge at 0x195c10f6e40>,
#   <matplotlib.patches.Wedge at 0x195c10f72f0>,
#   <matplotlib.patches.Wedge at 0x195c10f7740>,
#   <matplotlib.patches.Wedge at 0x195c10f7bf0>,
#   <matplotlib.patches.Wedge at 0x195c11240e0>,
#   <matplotlib.patches.Wedge at 0x195c1124560>,
#   <matplotlib.patches.Wedge at 0x195c11249e0>,
#   <matplotlib.patches.Wedge at 0x195c1124e90>,
#   <matplotlib.patches.Wedge at 0x195c1125310>,
#   <matplotlib.patches.Wedge at 0x195c1125790>,
#   <matplotlib.patches.Wedge at 0x195c1125c10>,
#   <matplotlib.patches.Wedge at 0x195c11260c0>,
#   <matplotlib.patches.Wedge at 0x195c1126510>,
#   <matplotlib.patches.Wedge at 0x195c1126990>,
#   <matplotlib.patches.Wedge at 0x195c1126e10>,
#   <matplotlib.patches.Wedge at 0x195c1127290>,
#   <matplotlib.patches.Wedge at 0x195c1127710>,
#   <matplotlib.patches.Wedge at 0x195c1127b60>,
#   <matplotlib.patches.Wedge at 0x195c1127fe0>,
#   <matplotlib.patches.Wedge at 0x195c11544a0>,
#   <matplotlib.patches.Wedge at 0x195c1154950>,
#   <matplotlib.patches.Wedge at 0x195c1154dd0>,
#   <matplotlib.patches.Wedge at 0x195c1155250>,
#   <matplotlib.patches.Wedge at 0x195c11556d0>,
#   <matplotlib.patches.Wedge at 0x195c1155b50>,
#   <matplotlib.patches.Wedge at 0x195c1155fd0>,
#   <matplotlib.patches.Wedge at 0x195c1156450>,
#   <matplotlib.patches.Wedge at 0x195c11568d0>,
#   <matplotlib.patches.Wedge at 0x195c1156d80>,
#   <matplotlib.patches.Wedge at 0x195c1157230>,
#   <matplotlib.patches.Wedge at 0x195c11576b0>,
#   <matplotlib.patches.Wedge at 0x195c1157950>,
#   <matplotlib.patches.Wedge at 0x195c1157f50>,
#   <matplotlib.patches.Wedge at 0x195c118c410>,
#   <matplotlib.patches.Wedge at 0x195c118c890>,
#   <matplotlib.patches.Wedge at 0x195c118cd10>,
#   <matplotlib.patches.Wedge at 0x195c118d190>,
#   <matplotlib.patches.Wedge at 0x195c118d610>,
#   <matplotlib.patches.Wedge at 0x195c118da90>,
#   <matplotlib.patches.Wedge at 0x195c118df10>,
#   <matplotlib.patches.Wedge at 0x195c118e3c0>,
#   <matplotlib.patches.Wedge at 0x195c118e840>,
#   <matplotlib.patches.Wedge at 0x195c118ec90>,
#   <matplotlib.patches.Wedge at 0x195c118f110>,
#   <matplotlib.patches.Wedge at 0x195c118f590>,
#   <matplotlib.patches.Wedge at 0x195c118fa10>,
#   <matplotlib.patches.Wedge at 0x195c118fec0>,
#   <matplotlib.patches.Wedge at 0x195c11c0350>,
#   <matplotlib.patches.Wedge at 0x195c11c07d0>,
#   <matplotlib.patches.Wedge at 0x195c11c0c80>,
#   <matplotlib.patches.Wedge at 0x195c11c1100>,
#   <matplotlib.patches.Wedge at 0x195c11c15b0>,
#   <matplotlib.patches.Wedge at 0x195c11c1a60>,
#   <matplotlib.patches.Wedge at 0x195c11c1f10>,
#   <matplotlib.patches.Wedge at 0x195c11c2390>,
#   <matplotlib.patches.Wedge at 0x195c11c2810>,
#   <matplotlib.patches.Wedge at 0x195c11c2cc0>,
#   <matplotlib.patches.Wedge at 0x195c11c3170>,
#   <matplotlib.patches.Wedge at 0x195c11c3620>,
#   <matplotlib.patches.Wedge at 0x195c11c3aa0>,
#   <matplotlib.patches.Wedge at 0x195c11c3f50>,
#   <matplotlib.patches.Wedge at 0x195c11f8440>,
#   <matplotlib.patches.Wedge at 0x195c11f88c0>,
#   <matplotlib.patches.Wedge at 0x195c11f8d70>,
#   <matplotlib.patches.Wedge at 0x195c11f91f0>,
#   <matplotlib.patches.Wedge at 0x195c11f96a0>,
#   <matplotlib.patches.Wedge at 0x195c11f9b20>,
#   <matplotlib.patches.Wedge at 0x195c11f9fa0>,
#   <matplotlib.patches.Wedge at 0x195c11fa420>,
#   <matplotlib.patches.Wedge at 0x195c11fa8a0>,
#   <matplotlib.patches.Wedge at 0x195c11fad20>,
#   <matplotlib.patches.Wedge at 0x195c11fb1d0>,
#   <matplotlib.patches.Wedge at 0x195c11fb440>,
#   <matplotlib.patches.Wedge at 0x195c11fbad0>,
#   <matplotlib.patches.Wedge at 0x195c11fbf50>,
#   <matplotlib.patches.Wedge at 0x195c122c3e0>,
#   <matplotlib.patches.Wedge at 0x195c122c890>,
#   <matplotlib.patches.Wedge at 0x195c122cd10>,
#   <matplotlib.patches.Wedge at 0x195c122d190>,
#   <matplotlib.patches.Wedge at 0x195c122d610>,
#   <matplotlib.patches.Wedge at 0x195c122da60>,
#   <matplotlib.patches.Wedge at 0x195c122deb0>,
#   <matplotlib.patches.Wedge at 0x195c122e360>,
#   <matplotlib.patches.Wedge at 0x195c122e810>,
#   <matplotlib.patches.Wedge at 0x195c122ec60>,
#   <matplotlib.patches.Wedge at 0x195c122f0e0>,
#   <matplotlib.patches.Wedge at 0x195c122f560>,
#   <matplotlib.patches.Wedge at 0x195c122fa10>,
#   <matplotlib.patches.Wedge at 0x195c122fec0>,
#   <matplotlib.patches.Wedge at 0x195c125c350>,
#   <matplotlib.patches.Wedge at 0x195c125c830>,
#   <matplotlib.patches.Wedge at 0x195c125ccb0>,
#   <matplotlib.patches.Wedge at 0x195c125d160>,
#   <matplotlib.patches.Wedge at 0x195c125d5e0>,
#   <matplotlib.patches.Wedge at 0x195c125da90>,
#   <matplotlib.patches.Wedge at 0x195c125dee0>,
#   <matplotlib.patches.Wedge at 0x195c125e360>,
#   <matplotlib.patches.Wedge at 0x195c125e810>,
#   <matplotlib.patches.Wedge at 0x195c125ec30>,
#   <matplotlib.patches.Wedge at 0x195c125f0b0>,
#   <matplotlib.patches.Wedge at 0x195c125f530>,
#   <matplotlib.patches.Wedge at 0x195c125f9b0>,
#   <matplotlib.patches.Wedge at 0x195c125fe30>,
#   <matplotlib.patches.Wedge at 0x195c12902f0>,
#   <matplotlib.patches.Wedge at 0x195c12907a0>,
#   <matplotlib.patches.Wedge at 0x195c1290bf0>,
#   <matplotlib.patches.Wedge at 0x195c1291070>,
#   <matplotlib.patches.Wedge at 0x195c12914f0>,
#   <matplotlib.patches.Wedge at 0x195c1291970>,
#   <matplotlib.patches.Wedge at 0x195c1291df0>,
#   <matplotlib.patches.Wedge at 0x195c12922a0>,
#   <matplotlib.patches.Wedge at 0x195c1292750>,
#   <matplotlib.patches.Wedge at 0x195c1292bd0>,
#   <matplotlib.patches.Wedge at 0x195c1293050>,
#   <matplotlib.patches.Wedge at 0x195c12934d0>,
#   <matplotlib.patches.Wedge at 0x195c1293950>,
#   <matplotlib.patches.Wedge at 0x195c1293da0>,
#   <matplotlib.patches.Wedge at 0x195c12c4290>,
#   <matplotlib.patches.Wedge at 0x195c12c4710>,
#   <matplotlib.patches.Wedge at 0x195c12c4b90>,
#   <matplotlib.patches.Wedge at 0x195c12c5070>,
#   <matplotlib.patches.Wedge at 0x195c12c54f0>,
#   <matplotlib.patches.Wedge at 0x195c12c5970>,
#   <matplotlib.patches.Wedge at 0x195c12c5e50>,
#   <matplotlib.patches.Wedge at 0x195c12c6300>,
#   <matplotlib.patches.Wedge at 0x195c12c6750>,
#   <matplotlib.patches.Wedge at 0x195c12c6c00>,
#   <matplotlib.patches.Wedge at 0x195c12c6f30>,
#   <matplotlib.patches.Wedge at 0x195c1292060>,
#   <matplotlib.patches.Wedge at 0x195c12c7950>,
#   <matplotlib.patches.Wedge at 0x195c12c7e00>,
#   <matplotlib.patches.Wedge at 0x195c12f82c0>,
#   <matplotlib.patches.Wedge at 0x195c12f87a0>,
#   <matplotlib.patches.Wedge at 0x195c12f8c20>,
#   <matplotlib.patches.Wedge at 0x195c12f90d0>,
#   <matplotlib.patches.Wedge at 0x195c12f94f0>,
#   <matplotlib.patches.Wedge at 0x195c12f97f0>,
#   <matplotlib.patches.Wedge at 0x195c12f9dc0>,
#   <matplotlib.patches.Wedge at 0x195c12fa240>,
#   <matplotlib.patches.Wedge at 0x195c12fa6c0>,
#   <matplotlib.patches.Wedge at 0x195c12fab70>,
#   <matplotlib.patches.Wedge at 0x195c12faff0>,
#   <matplotlib.patches.Wedge at 0x195c12f8e90>,
#   <matplotlib.patches.Wedge at 0x195c12fb890>,
#   <matplotlib.patches.Wedge at 0x195c12fbce0>,
#   <matplotlib.patches.Wedge at 0x195c132c1a0>,
#   <matplotlib.patches.Wedge at 0x195c132c650>,
#   <matplotlib.patches.Wedge at 0x195c132cad0>,
#   <matplotlib.patches.Wedge at 0x195c132cf50>,
#   <matplotlib.patches.Wedge at 0x195c132d3d0>,
#   <matplotlib.patches.Wedge at 0x195c132d850>,
#   <matplotlib.patches.Wedge at 0x195c132dd00>,
#   <matplotlib.patches.Wedge at 0x195c132e1b0>,
#   <matplotlib.patches.Wedge at 0x195c132e630>,
#   <matplotlib.patches.Wedge at 0x195c132e960>,
#   <matplotlib.patches.Wedge at 0x195c132ef90>,
#   <matplotlib.patches.Wedge at 0x195c132f3e0>,
#   <matplotlib.patches.Wedge at 0x195c132f890>,
#   <matplotlib.patches.Wedge at 0x195c132fd10>,
#   <matplotlib.patches.Wedge at 0x195c1360200>,
#   <matplotlib.patches.Wedge at 0x195c1360680>,
#   <matplotlib.patches.Wedge at 0x195c1360b00>,
#   <matplotlib.patches.Wedge at 0x195c1360f80>,
#   <matplotlib.patches.Wedge at 0x195c1361400>,
#   <matplotlib.patches.Wedge at 0x195c1361880>,
#   <matplotlib.patches.Wedge at 0x195c1361d30>,
#   <matplotlib.patches.Wedge at 0x195c1362180>,
#   <matplotlib.patches.Wedge at 0x195c1362600>,
#   <matplotlib.patches.Wedge at 0x195c1362ab0>,
#   <matplotlib.patches.Wedge at 0x195c1362f30>,
#   <matplotlib.patches.Wedge at 0x195c13633b0>,
#   <matplotlib.patches.Wedge at 0x195c1363830>,
#   <matplotlib.patches.Wedge at 0x195c1363c80>,
#   <matplotlib.patches.Wedge at 0x195c138c140>,
#   <matplotlib.patches.Wedge at 0x195c138c5c0>,
#   <matplotlib.patches.Wedge at 0x195c138c9e0>,
#   <matplotlib.patches.Wedge at 0x195c138ce90>,
#   <matplotlib.patches.Wedge at 0x195c138d310>,
#   <matplotlib.patches.Wedge at 0x195c138d790>,
#   <matplotlib.patches.Wedge at 0x195c138dc10>,
#   <matplotlib.patches.Wedge at 0x195c138e0c0>,
#   <matplotlib.patches.Wedge at 0x195c138e510>,
#   <matplotlib.patches.Wedge at 0x195c138e990>,
#   <matplotlib.patches.Wedge at 0x195c138ee10>,
#   <matplotlib.patches.Wedge at 0x195c138f290>,
#   <matplotlib.patches.Wedge at 0x195c138f710>,
#   <matplotlib.patches.Wedge at 0x195c138fb90>,
#   <matplotlib.patches.Wedge at 0x195c13c8050>,
#   <matplotlib.patches.Wedge at 0x195c13c84d0>,
#   <matplotlib.patches.Wedge at 0x195c13c8980>,
#   <matplotlib.patches.Wedge at 0x195c13c8e00>,
#   <matplotlib.patches.Wedge at 0x195c13c92b0>,
#   <matplotlib.patches.Wedge at 0x195c13c9760>,
#   <matplotlib.patches.Wedge at 0x195c13c9be0>,
#   <matplotlib.patches.Wedge at 0x195c13ca090>,
#   <matplotlib.patches.Wedge at 0x195c13ca510>,
#   <matplotlib.patches.Wedge at 0x195c13ca990>,
#   <matplotlib.patches.Wedge at 0x195c13cae70>,
#   <matplotlib.patches.Wedge at 0x195c13cb2c0>,
#   <matplotlib.patches.Wedge at 0x195c13cb740>,
#   <matplotlib.patches.Wedge at 0x195c13cbbf0>,
#   <matplotlib.patches.Wedge at 0x195c13fc0b0>,
#   <matplotlib.patches.Wedge at 0x195c13fc530>,
#   <matplotlib.patches.Wedge at 0x195c13fc9b0>,
#   <matplotlib.patches.Wedge at 0x195c13fce30>,
#   <matplotlib.patches.Wedge at 0x195c13fd310>,
#   <matplotlib.patches.Wedge at 0x195c13fd790>,
#   <matplotlib.patches.Wedge at 0x195c13fdc10>,
#   <matplotlib.patches.Wedge at 0x195c13fe090>,
#   <matplotlib.patches.Wedge at 0x195c13fe510>,
#   <matplotlib.patches.Wedge at 0x195c13fe960>,
#   <matplotlib.patches.Wedge at 0x195c13fee10>,
#   <matplotlib.patches.Wedge at 0x195c13ff290>,
#   <matplotlib.patches.Wedge at 0x195c13ff590>,
#   <matplotlib.patches.Wedge at 0x195c13ffb90>,
#   <matplotlib.patches.Wedge at 0x195c1430050>,
#   <matplotlib.patches.Wedge at 0x195c14304d0>,
#   <matplotlib.patches.Wedge at 0x195c1430950>,
#   <matplotlib.patches.Wedge at 0x195c1430e00>,
#   <matplotlib.patches.Wedge at 0x195c1431280>,
#   <matplotlib.patches.Wedge at 0x195c1431700>,
#   <matplotlib.patches.Wedge at 0x195c1431be0>,
#   <matplotlib.patches.Wedge at 0x195c1432030>,
#   <matplotlib.patches.Wedge at 0x195c14324b0>,
#   <matplotlib.patches.Wedge at 0x195c1432960>,
#   <matplotlib.patches.Wedge at 0x195c1432e10>,
#   <matplotlib.patches.Wedge at 0x195c14332c0>,
#   <matplotlib.patches.Wedge at 0x195c1433710>,
#   <matplotlib.patches.Wedge at 0x195c1433b90>,
#   <matplotlib.patches.Wedge at 0x195c1464050>,
#   <matplotlib.patches.Wedge at 0x195c14644d0>,
#   <matplotlib.patches.Wedge at 0x195c1464950>,
#   <matplotlib.patches.Wedge at 0x195c1464dd0>,
#   <matplotlib.patches.Wedge at 0x195c1465250>,
#   <matplotlib.patches.Wedge at 0x195c14656d0>,
#   <matplotlib.patches.Wedge at 0x195c1465b50>,
#   <matplotlib.patches.Wedge at 0x195c1465fd0>,
#   <matplotlib.patches.Wedge at 0x195c1466420>,
#   <matplotlib.patches.Wedge at 0x195c14668a0>,
#   <matplotlib.patches.Wedge at 0x195c1466d50>,
#   <matplotlib.patches.Wedge at 0x195c14671a0>,
#   <matplotlib.patches.Wedge at 0x195c1467620>,
#   <matplotlib.patches.Wedge at 0x195c1467ad0>,
#   <matplotlib.patches.Wedge at 0x195c1467fb0>,
#   <matplotlib.patches.Wedge at 0x195c14942f0>,
#   <matplotlib.patches.Wedge at 0x195c14948c0>,
#   <matplotlib.patches.Wedge at 0x195c1494d40>,
#   <matplotlib.patches.Wedge at 0x195c14951c0>,
#   <matplotlib.patches.Wedge at 0x195b5d7d6a0>,
#   <matplotlib.patches.Wedge at 0x195aad334d0>,
#   <matplotlib.patches.Wedge at 0x195bb14b170>,
#   <matplotlib.patches.Wedge at 0x195b4d1c590>,
#   <matplotlib.patches.Wedge at 0x195b9edc8c0>,
#   <matplotlib.patches.Wedge at 0x195bb3ac5c0>,
#   <matplotlib.patches.Wedge at 0x195bb3ac380>,
#   <matplotlib.patches.Wedge at 0x195bb3aca40>,
#   <matplotlib.patches.Wedge at 0x195bb3ad130>,
#   <matplotlib.patches.Wedge at 0x195bb3ad880>,
#   <matplotlib.patches.Wedge at 0x195bb3ade50>,
#   <matplotlib.patches.Wedge at 0x195bb3ae2a0>,
#   <matplotlib.patches.Wedge at 0x195bb3ae870>,
#   <matplotlib.patches.Wedge at 0x195bb3aef90>,
#   <matplotlib.patches.Wedge at 0x195bb3af3b0>,
#   <matplotlib.patches.Wedge at 0x195bb3af830>,
#   <matplotlib.patches.Wedge at 0x195bb3ae9c0>,
#   <matplotlib.patches.Wedge at 0x195bb3ac2f0>,
#   <matplotlib.patches.Wedge at 0x195b952dca0>,
#   <matplotlib.patches.Wedge at 0x195bfccf110>,
#   <matplotlib.patches.Wedge at 0x195bc5b0ec0>,
#   <matplotlib.patches.Wedge at 0x195bc5858b0>,
#   <matplotlib.patches.Wedge at 0x195bc585eb0>,
#   <matplotlib.patches.Wedge at 0x195bb2f4290>,
#   <matplotlib.patches.Wedge at 0x195bb2f4710>,
#   <matplotlib.patches.Wedge at 0x195bb2f4b90>,
#   <matplotlib.patches.Wedge at 0x195bb2f5010>,
#   <matplotlib.patches.Wedge at 0x195bb2f5430>,
#   <matplotlib.patches.Wedge at 0x195bb2f58b0>,
#   <matplotlib.patches.Wedge at 0x195bb2f5d30>,
#   <matplotlib.patches.Wedge at 0x195bb2f61e0>,
#   <matplotlib.patches.Wedge at 0x195bb2f6690>,
#   <matplotlib.patches.Wedge at 0x195bb2f6b40>,
#   <matplotlib.patches.Wedge at 0x195bb2f6fc0>,
#   <matplotlib.patches.Wedge at 0x195bb2f7440>,
#   <matplotlib.patches.Wedge at 0x195bb2f7920>,
#   <matplotlib.patches.Wedge at 0x195bb2f4050>,
#   <matplotlib.patches.Wedge at 0x195b8fc3080>,
#   <matplotlib.patches.Wedge at 0x195bad9f3b0>,
#   <matplotlib.patches.Wedge at 0x195bb3d6450>,
#   <matplotlib.patches.Wedge at 0x195bb3d62d0>,
#   <matplotlib.patches.Wedge at 0x195bb3d6c60>,
#   <matplotlib.patches.Wedge at 0x195bb3d5610>,
#   <matplotlib.patches.Wedge at 0x195bb3d4bf0>,
#   <matplotlib.patches.Wedge at 0x195bb3d4260>,
#   <matplotlib.patches.Wedge at 0x195bb3d6960>,
#   <matplotlib.patches.Wedge at 0x195bb3d4e90>,
#   <matplotlib.patches.Wedge at 0x195b7d80da0>,
#   <matplotlib.patches.Wedge at 0x195bb2b7e30>,
#   <matplotlib.patches.Wedge at 0x195bb2b75f0>,
#   <matplotlib.patches.Wedge at 0x195bbd5f6b0>,
#   <matplotlib.patches.Wedge at 0x195bccefb60>,
#   <matplotlib.patches.Wedge at 0x195bcd70650>,
#   <matplotlib.patches.Wedge at 0x195bcd73950>,
#   <matplotlib.patches.Wedge at 0x195bcd71130>,
#   <matplotlib.patches.Wedge at 0x195bcd714f0>,
#   <matplotlib.patches.Wedge at 0x195bcd70350>,
#   <matplotlib.patches.Wedge at 0x195bcd72d50>,
#   <matplotlib.patches.Wedge at 0x195bcd70800>,
#   <matplotlib.patches.Wedge at 0x195bcd735f0>,
#   <matplotlib.patches.Wedge at 0x195bcd74050>,
#   <matplotlib.patches.Wedge at 0x195bcd74800>,
#   <matplotlib.patches.Wedge at 0x195bcd74920>,
#   <matplotlib.patches.Wedge at 0x195bcd75700>,
#   <matplotlib.patches.Wedge at 0x195bcd75340>,
#   <matplotlib.patches.Wedge at 0x195aad539e0>,
#   <matplotlib.patches.Wedge at 0x195ba154d70>,
#   <matplotlib.patches.Wedge at 0x195b7d5d400>,
#   <matplotlib.patches.Wedge at 0x195bc527410>,
#   <matplotlib.patches.Wedge at 0x195bc526e70>,
#   <matplotlib.patches.Wedge at 0x195bc5269f0>,
#   <matplotlib.patches.Wedge at 0x195bc526900>,
#   <matplotlib.patches.Wedge at 0x195bc526450>,
#   <matplotlib.patches.Wedge at 0x195bc524dd0>,
#   <matplotlib.patches.Wedge at 0x195bc525c70>,
#   <matplotlib.patches.Wedge at 0x195bc5246e0>,
#   <matplotlib.patches.Wedge at 0x195bc524c20>,
#   <matplotlib.patches.Wedge at 0x195bc5248c0>,
#   <matplotlib.patches.Wedge at 0x195bc5240e0>,
#   <matplotlib.patches.Wedge at 0x195bbb611f0>,
#   <matplotlib.patches.Wedge at 0x195bbe0a5a0>,
#   <matplotlib.patches.Wedge at 0x195b7d40f20>,
#   <matplotlib.patches.Wedge at 0x195b7d0fef0>,
#   <matplotlib.patches.Wedge at 0x195bb334170>,
#   <matplotlib.patches.Wedge at 0x195bb3357c0>,
#   <matplotlib.patches.Wedge at 0x195bb3366c0>,
#   <matplotlib.patches.Wedge at 0x195bb336f30>,
#   <matplotlib.patches.Wedge at 0x195bb3372c0>,
#   <matplotlib.patches.Wedge at 0x195bb337740>,
#   <matplotlib.patches.Wedge at 0x195bb337bc0>,
#   <matplotlib.patches.Wedge at 0x195bb3343b0>,
#   <matplotlib.patches.Wedge at 0x195bb334d10>,
#   <matplotlib.patches.Wedge at 0x195bb2ec650>,
#   <matplotlib.patches.Wedge at 0x195bb2ed9a0>,
#   <matplotlib.patches.Wedge at 0x195bb2ef110>,
#   <matplotlib.patches.Wedge at 0x195bb2efc50>,
#   <matplotlib.patches.Wedge at 0x195bb2ef2f0>,
#   <matplotlib.patches.Wedge at 0x195bb2ec920>,
#   <matplotlib.patches.Wedge at 0x195bb2ee750>,
#   <matplotlib.patches.Wedge at 0x195bb2e8770>,
#   <matplotlib.patches.Wedge at 0x195bb2e95b0>,
#   <matplotlib.patches.Wedge at 0x195bb2ea570>,
#   <matplotlib.patches.Wedge at 0x195bb2eb1d0>,
#   <matplotlib.patches.Wedge at 0x195bb2ea030>,
#   <matplotlib.patches.Wedge at 0x195ba7180e0>,
#   <matplotlib.patches.Wedge at 0x195bb308200>,
#   <matplotlib.patches.Wedge at 0x195bb3086b0>,
#   <matplotlib.patches.Wedge at 0x195bb308b30>,
#   <matplotlib.patches.Wedge at 0x195bb308fe0>,
#   <matplotlib.patches.Wedge at 0x195bb309460>,
#   <matplotlib.patches.Wedge at 0x195bb3098e0>,
#   <matplotlib.patches.Wedge at 0x195bb309d00>,
#   <matplotlib.patches.Wedge at 0x195bb30a180>,
#   <matplotlib.patches.Wedge at 0x195bb30b9e0>,
#   <matplotlib.patches.Wedge at 0x195bb30ad50>,
#   <matplotlib.patches.Wedge at 0x195bb30b320>,
#   <matplotlib.patches.Wedge at 0x195bb30bb90>,
#   <matplotlib.patches.Wedge at 0x195bc381700>,
#   <matplotlib.patches.Wedge at 0x195bc4d30e0>,
#   <matplotlib.patches.Wedge at 0x195bc4d3770>,
#   <matplotlib.patches.Wedge at 0x195bc4d2d50>,
#   <matplotlib.patches.Wedge at 0x195bc4d2cc0>,
#   <matplotlib.patches.Wedge at 0x195bc4d20c0>,
#   <matplotlib.patches.Wedge at 0x195bc4d3ef0>,
#   <matplotlib.patches.Wedge at 0x195b4c394f0>,
#   <matplotlib.patches.Wedge at 0x195c1495730>,
#   <matplotlib.patches.Wedge at 0x195c1495bb0>,
#   <matplotlib.patches.Wedge at 0x195c1496060>,
#   <matplotlib.patches.Wedge at 0x195c14962d0>,
#   <matplotlib.patches.Wedge at 0x195c1496990>,
#   <matplotlib.patches.Wedge at 0x195c1496e10>,
#   <matplotlib.patches.Wedge at 0x195c1497290>,
#   <matplotlib.patches.Wedge at 0x195c1497710>,
#   <matplotlib.patches.Wedge at 0x195c1497b90>,
#   <matplotlib.patches.Wedge at 0x195c15a4050>,
#   <matplotlib.patches.Wedge at 0x195c15a44d0>,
#   <matplotlib.patches.Wedge at 0x195c15a4950>,
#   <matplotlib.patches.Wedge at 0x195c15a4dd0>,
#   <matplotlib.patches.Wedge at 0x195c15a5250>,
#   <matplotlib.patches.Wedge at 0x195c15a56d0>,
#   <matplotlib.patches.Wedge at 0x195c15a5b50>,
#   <matplotlib.patches.Wedge at 0x195c15a5fd0>,
#   <matplotlib.patches.Wedge at 0x195c15a6450>,
#   <matplotlib.patches.Wedge at 0x195c15a68d0>,
#   <matplotlib.patches.Wedge at 0x195c15a6d50>,
#   <matplotlib.patches.Wedge at 0x195c15a71d0>,
#   <matplotlib.patches.Wedge at 0x195c15a75f0>,
#   <matplotlib.patches.Wedge at 0x195c15a7aa0>,
#   <matplotlib.patches.Wedge at 0x195c15a7f50>,
#   <matplotlib.patches.Wedge at 0x195c15e03e0>,
#   <matplotlib.patches.Wedge at 0x195c15e0890>,
#   <matplotlib.patches.Wedge at 0x195c15e0d10>,
#   <matplotlib.patches.Wedge at 0x195c15e11c0>,
#   <matplotlib.patches.Wedge at 0x195c15e1640>,
#   <matplotlib.patches.Wedge at 0x195c15e1b20>,
#   <matplotlib.patches.Wedge at 0x195c15e1fa0>,
#   <matplotlib.patches.Wedge at 0x195c15e2450>,
#   <matplotlib.patches.Wedge at 0x195c15e28d0>,
#   <matplotlib.patches.Wedge at 0x195c15e2d80>,
#   <matplotlib.patches.Wedge at 0x195c15e3230>,
#   <matplotlib.patches.Wedge at 0x195c15e3440>,
#   <matplotlib.patches.Wedge at 0x195c15e3ad0>,
#   <matplotlib.patches.Wedge at 0x195c15e3e00>,
#   <matplotlib.patches.Wedge at 0x195c180c3e0>,
#   <matplotlib.patches.Wedge at 0x195c180c890>,
#   <matplotlib.patches.Wedge at 0x195c180cd10>,
#   <matplotlib.patches.Wedge at 0x195c180d190>,
#   <matplotlib.patches.Wedge at 0x195c180d610>,
#   <matplotlib.patches.Wedge at 0x195c180da90>,
#   <matplotlib.patches.Wedge at 0x195c180df10>,
#   <matplotlib.patches.Wedge at 0x195c180e3c0>,
#   <matplotlib.patches.Wedge at 0x195c180e810>,
#   <matplotlib.patches.Wedge at 0x195c180ecc0>,
#   <matplotlib.patches.Wedge at 0x195c180ef90>,
#   <matplotlib.patches.Wedge at 0x195c180f560>,
#   <matplotlib.patches.Wedge at 0x195c180fa10>,
#   <matplotlib.patches.Wedge at 0x195c180fec0>,
#   <matplotlib.patches.Wedge at 0x195c1844350>,
#   <matplotlib.patches.Wedge at 0x195c18447d0>,
#   <matplotlib.patches.Wedge at 0x195c1844c50>,
#   <matplotlib.patches.Wedge at 0x195c18450d0>,
#   <matplotlib.patches.Wedge at 0x195c1845550>,
#   <matplotlib.patches.Wedge at 0x195c18459d0>,
#   <matplotlib.patches.Wedge at 0x195c1845e20>,
#   <matplotlib.patches.Wedge at 0x195c1846300>,
#   <matplotlib.patches.Wedge at 0x195c1846750>,
#   <matplotlib.patches.Wedge at 0x195c1846c00>,
#   <matplotlib.patches.Wedge at 0x195c1847050>,
#   <matplotlib.patches.Wedge at 0x195c18474d0>,
#   <matplotlib.patches.Wedge at 0x195c1847950>,
#   <matplotlib.patches.Wedge at 0x195c1847dd0>,
#   <matplotlib.patches.Wedge at 0x195c1874290>,
#   <matplotlib.patches.Wedge at 0x195c1874710>,
#   <matplotlib.patches.Wedge at 0x195c1874b90>,
#   <matplotlib.patches.Wedge at 0x195c1875010>,
#   <matplotlib.patches.Wedge at 0x195c18754c0>,
#   <matplotlib.patches.Wedge at 0x195c1875910>,
#   <matplotlib.patches.Wedge at 0x195c1875d90>,
#   <matplotlib.patches.Wedge at 0x195c1876210>,
#   <matplotlib.patches.Wedge at 0x195c1876690>,
#   <matplotlib.patches.Wedge at 0x195c1876b10>,
#   <matplotlib.patches.Wedge at 0x195c1876f90>,
#   <matplotlib.patches.Wedge at 0x195c1877410>,
#   <matplotlib.patches.Wedge at 0x195c1877890>,
#   <matplotlib.patches.Wedge at 0x195c1877d10>,
#   <matplotlib.patches.Wedge at 0x195c18a81d0>,
#   <matplotlib.patches.Wedge at 0x195c18a8650>,
#   <matplotlib.patches.Wedge at 0x195c18a8ad0>,
#   <matplotlib.patches.Wedge at 0x195c18a8f50>,
#   <matplotlib.patches.Wedge at 0x195c18a93d0>,
#   <matplotlib.patches.Wedge at 0x195c18a9850>,
#   <matplotlib.patches.Wedge at 0x195c18a9cd0>,
#   <matplotlib.patches.Wedge at 0x195c18aa150>,
#   <matplotlib.patches.Wedge at 0x195c18aa5d0>,
#   <matplotlib.patches.Wedge at 0x195c18aaa50>,
#   <matplotlib.patches.Wedge at 0x195c18aaed0>,
#   <matplotlib.patches.Wedge at 0x195c18ab350>,
#   <matplotlib.patches.Wedge at 0x195c18ab7d0>,
#   <matplotlib.patches.Wedge at 0x195c18abc50>,
#   <matplotlib.patches.Wedge at 0x195c18e0110>,
#   <matplotlib.patches.Wedge at 0x195c18e0590>,
#   <matplotlib.patches.Wedge at 0x195c18e0a40>,
#   <matplotlib.patches.Wedge at 0x195c18e0e90>,
#   <matplotlib.patches.Wedge at 0x195c18e1310>,
#   <matplotlib.patches.Wedge at 0x195c18e1790>,
#   <matplotlib.patches.Wedge at 0x195c18e1c10>,
#   <matplotlib.patches.Wedge at 0x195c18e2090>,
#   <matplotlib.patches.Wedge at 0x195c18e2510>,
#   <matplotlib.patches.Wedge at 0x195c18e2990>,
#   <matplotlib.patches.Wedge at 0x195c18e2e10>,
#   <matplotlib.patches.Wedge at 0x195c18e32c0>,
#   <matplotlib.patches.Wedge at 0x195c18e3710>,
#   <matplotlib.patches.Wedge at 0x195c18e3b90>,
#   <matplotlib.patches.Wedge at 0x195c1910050>,
#   <matplotlib.patches.Wedge at 0x195c19104d0>,
#   <matplotlib.patches.Wedge at 0x195c1910950>,
#   <matplotlib.patches.Wedge at 0x195c1910dd0>,
#   <matplotlib.patches.Wedge at 0x195c1911250>,
#   <matplotlib.patches.Wedge at 0x195c19116d0>,
#   <matplotlib.patches.Wedge at 0x195c1911b50>,
#   <matplotlib.patches.Wedge at 0x195c1911fd0>,
#   <matplotlib.patches.Wedge at 0x195c1912450>,
#   <matplotlib.patches.Wedge at 0x195c19128d0>,
#   <matplotlib.patches.Wedge at 0x195c1912d50>,
#   <matplotlib.patches.Wedge at 0x195c19131d0>,
#   <matplotlib.patches.Wedge at 0x195c1913440>,
#   <matplotlib.patches.Wedge at 0x195c1913ad0>,
#   <matplotlib.patches.Wedge at 0x195c1913f50>,
#   <matplotlib.patches.Wedge at 0x195c194c410>,
#   <matplotlib.patches.Wedge at 0x195c194c890>,
#   <matplotlib.patches.Wedge at 0x195c194cd10>,
#   <matplotlib.patches.Wedge at 0x195c194d190>,
#   <matplotlib.patches.Wedge at 0x195c194d610>,
#   <matplotlib.patches.Wedge at 0x195c194da90>,
#   <matplotlib.patches.Wedge at 0x195c194df10>,
#   <matplotlib.patches.Wedge at 0x195c194e3c0>,
#   <matplotlib.patches.Wedge at 0x195c194e810>,
#   <matplotlib.patches.Wedge at 0x195c194ecc0>,
#   <matplotlib.patches.Wedge at 0x195c194f110>,
#   <matplotlib.patches.Wedge at 0x195c194f590>,
#   <matplotlib.patches.Wedge at 0x195c194fa10>,
#   <matplotlib.patches.Wedge at 0x195c194fec0>,
#   <matplotlib.patches.Wedge at 0x195c197c350>,
#   <matplotlib.patches.Wedge at 0x195c197c7d0>,
#   <matplotlib.patches.Wedge at 0x195c197cc50>,
#   <matplotlib.patches.Wedge at 0x195c197d0d0>,
#   <matplotlib.patches.Wedge at 0x195c197d550>,
#   <matplotlib.patches.Wedge at 0x195c197d9d0>,
#   <matplotlib.patches.Wedge at 0x195c197de50>,
#   <matplotlib.patches.Wedge at 0x195c197e300>,
#   <matplotlib.patches.Wedge at 0x195c197e750>,
#   <matplotlib.patches.Wedge at 0x195c197ec00>,
#   <matplotlib.patches.Wedge at 0x195c197f050>,
#   <matplotlib.patches.Wedge at 0x195c197f4d0>,
#   <matplotlib.patches.Wedge at 0x195c197f950>,
#   <matplotlib.patches.Wedge at 0x195c197fdd0>,
#   <matplotlib.patches.Wedge at 0x195c19b0290>,
#   <matplotlib.patches.Wedge at 0x195c19b0710>,
#   <matplotlib.patches.Wedge at 0x195c19b0b90>,
#   <matplotlib.patches.Wedge at 0x195c19b1040>,
#   <matplotlib.patches.Wedge at 0x195c19b1490>,
#   <matplotlib.patches.Wedge at 0x195c19b1910>,
#   <matplotlib.patches.Wedge at 0x195c19b1d90>,
#   <matplotlib.patches.Wedge at 0x195c19b2210>,
#   <matplotlib.patches.Wedge at 0x195c19b2690>,
#   <matplotlib.patches.Wedge at 0x195c19b2b10>,
#   <matplotlib.patches.Wedge at 0x195c19b2f90>,
#   <matplotlib.patches.Wedge at 0x195c19b3410>,
#   <matplotlib.patches.Wedge at 0x195c19b3890>,
#   <matplotlib.patches.Wedge at 0x195c19b3d40>,
#   <matplotlib.patches.Wedge at 0x195c19e8200>,
#   <matplotlib.patches.Wedge at 0x195c19e8680>,
#   <matplotlib.patches.Wedge at 0x195c19e8b00>,
#   <matplotlib.patches.Wedge at 0x195c19e8f80>,
#   <matplotlib.patches.Wedge at 0x195c19e9400>,
#   <matplotlib.patches.Wedge at 0x195c19e9880>,
#   <matplotlib.patches.Wedge at 0x195c19e9d00>,
#   <matplotlib.patches.Wedge at 0x195c19ea180>,
#   <matplotlib.patches.Wedge at 0x195c19ea600>,
#   <matplotlib.patches.Wedge at 0x195c19eaa80>,
#   <matplotlib.patches.Wedge at 0x195c19eaf00>,
#   <matplotlib.patches.Wedge at 0x195c19eb380>,
#   <matplotlib.patches.Wedge at 0x195c19eb830>,
#   <matplotlib.patches.Wedge at 0x195c19ebce0>,
#   <matplotlib.patches.Wedge at 0x195c1a181d0>,
#   <matplotlib.patches.Wedge at 0x195c1a18650>,
#   <matplotlib.patches.Wedge at 0x195c1a18ad0>,
#   <matplotlib.patches.Wedge at 0x195c1a18f50>,
#   <matplotlib.patches.Wedge at 0x195c1a193d0>,
#   <matplotlib.patches.Wedge at 0x195c1a19850>,
#   <matplotlib.patches.Wedge at 0x195c1a19cd0>,
#   <matplotlib.patches.Wedge at 0x195c1a1a150>,
#   <matplotlib.patches.Wedge at 0x195c1a1a5d0>,
#   <matplotlib.patches.Wedge at 0x195c1a1aa50>,
#   <matplotlib.patches.Wedge at 0x195c1a1aed0>,
#   <matplotlib.patches.Wedge at 0x195c1a1b350>,
#   <matplotlib.patches.Wedge at 0x195c1a1b7d0>,
#   <matplotlib.patches.Wedge at 0x195c1a1bc50>,
#   <matplotlib.patches.Wedge at 0x195c1a50110>,
#   <matplotlib.patches.Wedge at 0x195c1a50590>,
#   <matplotlib.patches.Wedge at 0x195c1a50a40>,
#   <matplotlib.patches.Wedge at 0x195c1a50e90>,
#   <matplotlib.patches.Wedge at 0x195c1a51310>,
#   <matplotlib.patches.Wedge at 0x195c1a51790>,
#   <matplotlib.patches.Wedge at 0x195c1a51c10>,
#   <matplotlib.patches.Wedge at 0x195c1a52090>,
#   <matplotlib.patches.Wedge at 0x195c1a52510>,
#   <matplotlib.patches.Wedge at 0x195c1a52990>,
#   <matplotlib.patches.Wedge at 0x195c1a52e10>,
#   <matplotlib.patches.Wedge at 0x195c1a532c0>,
#   <matplotlib.patches.Wedge at 0x195c1a53710>,
#   <matplotlib.patches.Wedge at 0x195c1a53b90>,
#   <matplotlib.patches.Wedge at 0x195c1a84050>,
#   <matplotlib.patches.Wedge at 0x195c1a844d0>,
#   <matplotlib.patches.Wedge at 0x195c1a84950>,
#   <matplotlib.patches.Wedge at 0x195c1a84dd0>,
#   <matplotlib.patches.Wedge at 0x195c1a85250>,
#   <matplotlib.patches.Wedge at 0x195c1a856d0>,
#   <matplotlib.patches.Wedge at 0x195c1a85b50>,
#   <matplotlib.patches.Wedge at 0x195c1a85fd0>,
#   <matplotlib.patches.Wedge at 0x195c1a86450>,
#   <matplotlib.patches.Wedge at 0x195c1a868d0>,
#   <matplotlib.patches.Wedge at 0x195c1a86d50>,
#   <matplotlib.patches.Wedge at 0x195c1a871d0>,
#   <matplotlib.patches.Wedge at 0x195c1a87650>,
#   <matplotlib.patches.Wedge at 0x195c1a87ad0>,
#   <matplotlib.patches.Wedge at 0x195c1a87f80>,
#   <matplotlib.patches.Wedge at 0x195c1ab4410>,
#   <matplotlib.patches.Wedge at 0x195c1ab4890>,
#   <matplotlib.patches.Wedge at 0x195c1ab4d10>,
#   <matplotlib.patches.Wedge at 0x195c1ab5190>,
#   <matplotlib.patches.Wedge at 0x195c1ab5610>,
#   <matplotlib.patches.Wedge at 0x195c1ab5a90>,
#   <matplotlib.patches.Wedge at 0x195c1ab5f10>,
#   <matplotlib.patches.Wedge at 0x195c1ab63c0>,
#   <matplotlib.patches.Wedge at 0x195c1ab6810>,
#   <matplotlib.patches.Wedge at 0x195c1ab6cc0>,
#   <matplotlib.patches.Wedge at 0x195c1ab7110>,
#   <matplotlib.patches.Wedge at 0x195c1ab7590>,
#   <matplotlib.patches.Wedge at 0x195c1ab7a10>,
#   <matplotlib.patches.Wedge at 0x195c1ab7ec0>,
#   <matplotlib.patches.Wedge at 0x195c1aec350>,
#   <matplotlib.patches.Wedge at 0x195c1aec7d0>,
#   <matplotlib.patches.Wedge at 0x195c1aecc50>,
#   <matplotlib.patches.Wedge at 0x195c1aed0d0>,
#   <matplotlib.patches.Wedge at 0x195c1aed550>,
#   <matplotlib.patches.Wedge at 0x195c1aed9d0>,
#   <matplotlib.patches.Wedge at 0x195c1aede50>,
#   <matplotlib.patches.Wedge at 0x195c1aee300>,
#   <matplotlib.patches.Wedge at 0x195c1aee750>,
#   <matplotlib.patches.Wedge at 0x195c1aeec00>,
#   <matplotlib.patches.Wedge at 0x195c1aef050>,
#   <matplotlib.patches.Wedge at 0x195c1aef4d0>,
#   <matplotlib.patches.Wedge at 0x195c1aef950>,
#   <matplotlib.patches.Wedge at 0x195c1aefdd0>,
#   <matplotlib.patches.Wedge at 0x195c1b1c290>,
#   <matplotlib.patches.Wedge at 0x195c1b1c710>,
#   <matplotlib.patches.Wedge at 0x195c1b1cb90>,
#   <matplotlib.patches.Wedge at 0x195c1b1d010>,
#   <matplotlib.patches.Wedge at 0x195c1b1d4c0>,
#   <matplotlib.patches.Wedge at 0x195c1b1d910>,
#   <matplotlib.patches.Wedge at 0x195c1b1dd90>,
#   <matplotlib.patches.Wedge at 0x195c1b1e210>,
#   <matplotlib.patches.Wedge at 0x195c1b1e690>,
#   <matplotlib.patches.Wedge at 0x195c1b1eb10>,
#   <matplotlib.patches.Wedge at 0x195c1b1ef90>,
#   <matplotlib.patches.Wedge at 0x195c1b1f410>,
#   <matplotlib.patches.Wedge at 0x195c1b1f890>,
#   <matplotlib.patches.Wedge at 0x195c1b1fd10>,
#   <matplotlib.patches.Wedge at 0x195c1b501d0>,
#   <matplotlib.patches.Wedge at 0x195c1b50650>,
#   <matplotlib.patches.Wedge at 0x195c1b50ad0>,
#   <matplotlib.patches.Wedge at 0x195c1b50f50>,
#   <matplotlib.patches.Wedge at 0x195c1b513d0>,
#   <matplotlib.patches.Wedge at 0x195c1b51850>,
#   <matplotlib.patches.Wedge at 0x195c1b51cd0>,
#   <matplotlib.patches.Wedge at 0x195c1b52150>,
#   <matplotlib.patches.Wedge at 0x195c1b525d0>,
#   <matplotlib.patches.Wedge at 0x195c1b52a50>,
#   <matplotlib.patches.Wedge at 0x195c1b52ed0>,
#   <matplotlib.patches.Wedge at 0x195c1b53350>,
#   <matplotlib.patches.Wedge at 0x195c1b537d0>,
#   <matplotlib.patches.Wedge at 0x195c1b53c50>,
#   <matplotlib.patches.Wedge at 0x195c1b88110>,
#   <matplotlib.patches.Wedge at 0x195c1b88590>,
#   <matplotlib.patches.Wedge at 0x195c1b88a40>,
#   <matplotlib.patches.Wedge at 0x195c1b88e90>,
#   <matplotlib.patches.Wedge at 0x195c1b89310>,
#   <matplotlib.patches.Wedge at 0x195c1b89790>,
#   <matplotlib.patches.Wedge at 0x195c1b89c10>,
#   <matplotlib.patches.Wedge at 0x195c1b8a090>,
#   <matplotlib.patches.Wedge at 0x195c1b8a510>,
#   <matplotlib.patches.Wedge at 0x195c1b8a990>,
#   <matplotlib.patches.Wedge at 0x195c1b8ae10>,
#   <matplotlib.patches.Wedge at 0x195c1b8b2c0>,
#   <matplotlib.patches.Wedge at 0x195c1b8b710>,
#   <matplotlib.patches.Wedge at 0x195c1b8bb90>,
#   <matplotlib.patches.Wedge at 0x195c1bb8050>,
#   <matplotlib.patches.Wedge at 0x195c1bb84d0>,
#   <matplotlib.patches.Wedge at 0x195c1bb8950>,
#   <matplotlib.patches.Wedge at 0x195c1bb8dd0>,
#   <matplotlib.patches.Wedge at 0x195c1bb9250>,
#   <matplotlib.patches.Wedge at 0x195c1bb96d0>,
#   <matplotlib.patches.Wedge at 0x195c1bb9b50>,
#   <matplotlib.patches.Wedge at 0x195c1bb9fd0>,
#   <matplotlib.patches.Wedge at 0x195c1bba450>],
#  [Text(1.0999901272186052, 0.004660474396107649, '2023'),
#   Text(1.0999382955981591, 0.011651003245082137, '2023'),
#   Text(1.0998790604517883, 0.016311112153730906, '2023'),
#   Text(1.099800081948276, 0.020970926220969664, '2019'),
#   Text(1.0997013614358842, 0.025630365897955112, '2023'),
#   Text(1.0995162685220747, 0.032618633559563244, '2023'),
#   Text(1.0992004004607903, 0.04193422977518852, '2023'),
#   Text(1.098911703802931, 0.048918986548571686, '2023'),
#   Text(1.0986945811511217, 0.05357440946161886, '2023'),
#   Text(1.0983319196318735, 0.06055571251140295, '2023'),
#   Text(1.0977793685806077, 0.06986027425341554, '2023'),
#   Text(1.0973132259052125, 0.07683543618341807, '2023'),
#   Text(1.0969778410639954, 0.08148384020513383, '2023'),
#   Text(1.0966227648876454, 0.08613078154862099, '2023'),
#   Text(1.0962480037499684, 0.09077617679881322, '2022'),
#   Text(1.0958535643781262, 0.09541994256839745, '2022'),
#   Text(1.095439453852515, 0.10006199549931062, '2023'),
#   Text(1.0950056796066385, 0.10470225226423603, '2023'),
#   Text(1.0943181671396178, 0.11165907517164714, '2023'),
#   Text(1.0935864541762277, 0.11861141278252131, '2023'),
#   Text(1.0925421393515782, 0.1278736632034788, '2023'),
#   Text(1.0914193772854748, 0.13712674022883617, '2023'),
#   Text(1.0908286022567937, 0.1417496402058577, '2013'),
#   Text(1.089905730923313, 0.14867917709120734, '2023'),
#   Text(1.0882698104040789, 0.16021491741741908, '2023'),
#   Text(1.0868731590083325, 0.16943062364061598, '2023'),
#   Text(1.0857744476145463, 0.17633448019978154, '2022'),
#   Text(1.0842412938677841, 0.1855284794092642, '2023'),
#   Text(1.0830403307993843, 0.19241528489691298, '2023'),
#   Text(1.0822153900812177, 0.19700215600687737, '2023'),
#   Text(1.0813710142151531, 0.20158553920182676, '2023'),
